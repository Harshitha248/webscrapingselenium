# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]


url="https://www.naukri.com/job-listings-eton-solutions-a-fintech-company-data-scientist-immediate-joiner-eton-solutions-and-technologies-india-llp-bangalore-bengaluru-7-to-12-years-290321000719?src=jobsearchDesk&amp;sid=16176100821319937&amp;xp=17&amp;px=1"

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)
    

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs

url="https://www.naukri.com/job-listings-opportunity-for-data-scientist-internship-bengaluru-corner-stone-solutions-bangalore-bengaluru-0-to-1-years-240620007489?src=jobsearchDesk&amp;sid=16175519552351389&amp;xp=2&amp;px=1"

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)
    

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
# 1 2 1
#                                                title                 company  \
# 0  Opportunity For Data Scientist Internship - Be...  Corner Stone Solutions
#
#               location
# 0  Bangalore/Bengaluru

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]


url="https://www.naukri.com/job-listings-data-scientist-fractal-analytics-ltd-bengaluru-bangalore-3-to-7-years-311220500303?src=jobsearchDesk&amp;sid=16175480409844011&amp;xp=1&amp;px=1"

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)
    

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs

url="https://www.naukri.com/job-listings-opportunity-for-data-scientist-internship-bengaluru-corner-stone-solutions-bangalore-bengaluru-0-to-1-years-240620007489?src=jobsearchDesk&amp;sid=16175519552351389&amp;xp=2&amp;px=1"

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)
    

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
# 1 2 1
#                                                title                 company  \
# 0  Opportunity For Data Scientist Internship - Be...  Corner Stone Solutions
#
#               location
# 0  Bangalore/Bengaluru

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]

url="https://www.naukri.com/job-listings-data-scientist-analyst-becton-dickinson-india-pvt-ltd-bangalore-bengaluru-5-to-10-years-220321002877?src=jobsearchDesk&amp;sid=16176020847664509&amp;xp=3&amp;px=1" 

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)
    

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
#                      title                          company  \
# 0  Data Scientist/ Analyst  Becton Dickinson India Pvt. Ltd
#
#               location
# 0  Bangalore/Bengaluru

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup

# %%
search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

# %%
search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

# %%
search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

# %%
#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

# %%
#lets open the webpage through our webdriver
browser.get(url)

# %%
job_titles=[]
company_names=[]
location_list=[]

# %%
url="https://www.naukri.com/job-listings-senior-data-scientist-avom-consultants-pune-bangalore-bengaluru-delhi-ncr-5-to-10-years-310321009535?src=jobsearchDesk&amp;sid=16176027354837535&amp;xp=4&amp;px=1"

# %%
#lets open the webpage through our webdriver
browser.get(url)

# %%
title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0fac50ca15270d78b7261c3d1b4e5ea6", element="b120d854-7167-4e6d-a8d6-c324b5031d8c")>]

# %%
job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

# %%
job_title
# Out:
# ['Senior Data Scientist']

# %%
location_tags = browser.find_elements_by_class_name("location")
location_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0fac50ca15270d78b7261c3d1b4e5ea6", element="fbbc276a-bbb9-4248-8f10-01919095e659")>]

# %%
location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)

# %%
location_name
# Out:
# ['Pune, Bangalore/Bengaluru, Delhi / NCR']

# %%
company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0fac50ca15270d78b7261c3d1b4e5ea6", element="b318aabe-5241-4d0d-baa3-3f2a55ff4555")>

# %%
company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)

# %%
company_name
# Out:
# ['Avom Consultants', '']

# %%
print(len(job_title), len(company_name), len(location_name))
# Out:
# 1 2 1

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

# %%
jobs
# Out:
#                    title           company  \
# 0  Senior Data Scientist  Avom Consultants
#
#                                  location
# 0  Pune, Bangalore/Bengaluru, Delhi / NCR

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]

url="https://www.naukri.com/job-listings-dbcg-ind-gamma-senior-data-scientist-boston-consulting-group-mumbai-new-delhi-chennai-bangalore-bengaluru-6-to-10-years-020421500121?src=jobsearchDesk&amp;sid=16176054210885197&amp;xp=6&amp;px=1"

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
#                                     title                  company  \
# 0  DBCG IND - GAMMA Senior Data Scientist  Boston Consulting Group
#
#                                           location
# 0  Mumbai, New Delhi, Chennai, Bangalore/Bengaluru

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup

search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

url="https://www.naukri.com/job-listings-data-scientist-dun-bradstreet-information-services-india-private-limited-bangalore-bengaluru-2-to-5-years-010421501056?src=jobsearchDesk&amp;sid=16176059834922478&amp;xp=12&amp;px=1" 

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
#             title                                            company  \
# 0  Data Scientist  DUN & BRADSTREET INFORMATION SERVICES INDIA PR...
#
#               location
# 0  Bangalore/Bengaluru

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]

url="https://www.naukri.com/job-listings-data-scientist-scalein-bengaluru-bangalore-4-to-9-years-300119501757?src=jobsearchDesk&amp;sid=16176067935361601&amp;xp=12&amp;px=1" 

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
#             title  company             location
# 0  Data Scientist  ScaleIn  Bangalore/Bengaluru

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]

url="https://www.naukri.com/job-listings-data-scientist-image-processing-machine-learning-carbynetech-india-hyderabad-secunderabad-6-to-11-years-031120900445?src=jobsearchDesk&amp;sid=16176073434688322&amp;xp=10&amp;px=1"  

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
#                                                title            company  \
# 0  Data Scientist - Image Processing/Machine Lear...  CarbyneTech India
#
#                  location
# 0  Hyderabad/Secunderabad

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]

url="https://www.naukri.com/job-listings-data-scientist-data-analyst-immediate-inflexion-analytix-private-limited-hyderabad-secunderabad-pune-chennai-bangalore-bengaluru-0-to-2-years-160221001218?src=jobsearchDesk&amp;sid=1617607701440816&amp;xp=11&amp;px=1"   

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
#                                    title                             company  \
# 0  Data Scientist/Data Analyst-immediate  Inflexion Analytix Private Limited
#
#                                             location
# 0  Hyderabad/Secunderabad, Pune, Chennai, Bangalo...

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com")
from bs4 import BeautifulSoup


search_job = browser.find_element_by_id("qsb-keyword-sugg")
search_job.send_keys("Data Scientist")

search_loc = browser.find_element_by_id ("qsb-location-sugg")
search_loc.send_keys("Banglore")

search_btn = browser.find_element_by_class_name ("btn")
search_btn.click()

#specifying the URL of webpage to be scraped
url="https://www.naukri.com/data-scientist-jobs-in-banglore?k=data%20scientist&l=banglore"

#lets open the webpage through our webdriver
browser.get(url)

job_titles=[]
company_names=[]
location_list=[]

url="https://www.naukri.com/job-listings-senior-data-scientist-ces-it-ltd-cmmi-level-5-ces-ltd-kolkata-mumbai-hyderabad-secunderabad-pune-chennai-bangalore-bengaluru-delhi-ncr-2-to-7-years-151220006902?src=jobsearchDesk&amp;sid=16176089563399294&amp;xp=8&amp;px=1"   

#lets open the webpage through our webdriver
browser.get(url)

title_tags = browser.find_elements_by_xpath ("//h1[@class='jd-header-title']")
title_tags

job_title=[]
for i in title_tags:
    title=i.text
    job_title.append(title)

job_title

location_tags = browser.find_elements_by_class_name("location")
location_tags

location_name=[]
for i in location_tags:
    location=i.text
    location_name.append(location)

location_name

company_tags = browser.find_elements_by_xpath("//a[@class='pad-rt-8']")
company_tags[0]

company_name=[]
for i in company_tags:
    company=i.text
    company_name.append(company)
    

company_name

print(len(job_title), len(company_name), len(location_name))

import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_title
jobs['company']=company_name[0:1]
jobs['location']=location_name

jobs
# Out:
# 1 2 1
#                                                title   company  \
# 0  Senior Data Scientist | CES IT LTD | CMMI Level 5  CES Ltd.
#
#                                             location
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
